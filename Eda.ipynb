# %%
# !pip install librosa matplotlib numpy

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

def extract_features(file_path):
    y, sr = librosa.load(file_path, sr=None)
    # Extract features, e.g., MFCCs, Chroma, etc.
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    return mfcc, sr

# Replace 'your_file.mp3' with the path to your MP3 file
file_path = r'D:\Tag\Vocal Gender Classifier\Megham Karukatha.mp3'
mfcc, sr = extract_features(file_path)

# %%
def dummy_predict(mfcc):
    # Dummy predictions: replace with your actual model predictions
    length = mfcc.shape[1]
    male_voice = np.random.choice([0, 1], size=(length,), p=[0.8, 0.2])
    female_voice = np.random.choice([0, 1], size=(length,), p=[0.7, 0.3])
    chorus_voice = np.random.choice([0, 1], size=(length,), p=[0.9, 0.1])
    return male_voice, female_voice, chorus_voice

male_voice, female_voice, chorus_voice = dummy_predict(mfcc)

# %%
def visualize_predictions(male_voice, female_voice, chorus_voice, sr):
    time = np.arange(0, len(male_voice)) * (1 / sr)
    plt.figure(figsize=(15, 6))

    plt.plot(time, male_voice, label='Male Voice', color='blue', drawstyle='steps-post')
    plt.plot(time, female_voice, label='Female Voice', color='red', drawstyle='steps-post')
    plt.plot(time, chorus_voice, label='Chorus Voice', color='green', drawstyle='steps-post')

    plt.xlabel('Time (seconds)')
    plt.ylabel('Presence (0 or 1)')
    plt.title('Voice Presence Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

visualize_predictions(male_voice, female_voice, chorus_voice, sr)

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

def extract_features(file_path):
    y, sr = librosa.load(file_path, sr=None)
    # Extract features, e.g., MFCCs
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    return mfcc, sr

# Replace 'your_file.mp3' with the path to your MP3 file
file_path = r'D:\Tag\Vocal Gender Classifier\Megham Karukatha.mp3'
mfcc, sr = extract_features(file_path)

# %%
def dummy_predict(mfcc):
    # Dummy predictions: replace with your actual model predictions
    length = mfcc.shape[1]
    male_voice = np.random.choice([0, 1], size=(length,), p=[0.8, 0.2])
    female_voice = np.random.choice([0, 1], size=(length,), p=[0.7, 0.3])
    return male_voice, female_voice

male_voice, female_voice = dummy_predict(mfcc)

# %%
def visualize_predictions(male_voice, female_voice, sr):
    time = np.arange(0, len(male_voice)) * (1 / sr)
    plt.figure(figsize=(15, 6))

    plt.plot(time, male_voice, label='Male Voice', color='blue', drawstyle='steps-post')
    plt.plot(time, female_voice, label='Female Voice', color='red', drawstyle='steps-post')

    plt.xlabel('Time (seconds)')
    plt.ylabel('Presence (0 or 1)')
    plt.title('Voice Presence Over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

visualize_predictions(male_voice, female_voice, sr)

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

def extract_features(file_path):
    y, sr = librosa.load(file_path, sr=None)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr).mean()
    rmse = librosa.feature.rms(y=y).mean()
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr).mean()
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr).mean()
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr).mean()
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y=y).mean()
    harmony = librosa.effects.harmonic(y=y).mean()
    perceptual_spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr).mean()
    tonnetz = librosa.feature.tonnetz(y=y, sr=sr).mean()
    
    features = np.array([chroma_stft, rmse, spectral_centroid, spectral_bandwidth, rolloff, zero_crossing_rate, harmony, perceptual_spectral_contrast, tonnetz])
    
    return features

def display_features(features):
    feature_names = ['Chroma STFT', 'RMSE', 'Spectral Centroid', 'Spectral Bandwidth', 'Spectral Rolloff', 'Zero Crossing Rate', 'Harmony', 'Perceptual Spectral Contrast', 'Tonnetz']
    
    plt.figure(figsize=(10, 6))
    plt.bar(feature_names, features)
    plt.xlabel('Feature')
    plt.ylabel('Value')
    plt.title('Audio Features')
    plt.xticks(rotation=45)
    plt.show()

# Example usage:
file_path = r'D:\Tag\Vocal Gender Classifier\Dataset\Male\male_song_4.mp3'
features = extract_features(file_path)
display_features(features)
